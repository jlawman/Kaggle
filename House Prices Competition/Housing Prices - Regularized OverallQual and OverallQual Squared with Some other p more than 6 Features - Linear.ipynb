# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train=pd.read_csv('data/Housing/train.csv')
test=pd.read_csv('data/Housing/test.csv')
sample_submission=pd.read_csv('data/Housing/sample_submission.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## Some first exploration of features

# %%
train.corr()  #Look for items with high correlation
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# Correlation with saleprice:
# >\>.7
# GrLivArea
# OverallQual
#
# >\>.6
# GarageArea
# GarageCars
# TotalBsmtSF
# 1stFlrSF
#
# >\>.5
# FullBath
# TotRmsAbvGrd
# YearBuilt
# YearRemodAdd
#
# >\>.4
# MasVnrArea
# Fireplaces
# GarageYrBlt

# %%
sns.jointplot(x='OverallQual',y='SalePrice',data=train)

# %%
#Most influential features (p>.4)
train[['GrLivArea', 'OverallQual', 'GarageArea', 'GarageCars', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd','MasVnrArea','Fireplaces','GarageYrBlt','SalePrice']].corr()
# Out:
#               GrLivArea  OverallQual  GarageArea  GarageCars  TotalBsmtSF  \
# GrLivArea      1.000000     0.593007    0.468997    0.467247     0.454868
# OverallQual    0.593007     1.000000    0.562022    0.600671     0.537808
# GarageArea     0.468997     0.562022    1.000000    0.882475     0.486665
# GarageCars     0.467247     0.600671    0.882475    1.000000     0.434585
# TotalBsmtSF    0.454868     0.537808    0.486665    0.434585     1.000000
# 1stFlrSF       0.566024     0.476224    0.489782    0.439317     0.819530
# FullBath       0.630012     0.550600    0.405656    0.469672     0.323722
# TotRmsAbvGrd   0.825489     0.427452    0.337822    0.362289     0.285573
# YearBuilt      0.199010     0.572323    0.478954    0.537850     0.391452
# YearRemodAdd   0.287389     0.550684    0.371600    0.420622     0.291066
# MasVnrArea     0.390857     0.411876    0.373066    0.364204     0.363936
# Fireplaces     0.461679     0.396765    0.269141    0.300789     0.339519
# ...

# %%
#Highly influential select features with (p>.6)
hi_inf_train=train[['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF','OverallQual']]
hi_inf_train.head()
# Out:
#    GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF  OverallQual
# 0       1710         548          856       856            7
# 1       1262         460         1262      1262            6
# 2       1786         608          920       920            7
# 3       1717         642          756       961            7
# 4       2198         836         1145      1145            8

# %%
hi_inf_train['OverallQualReg']=hi_inf_train['OverallQual']*300
hi_inf_train['OverallQualSquared']=(hi_inf_train['OverallQualReg']*hi_inf_train['OverallQualReg'])/5000 #squared and divided by 5,000 to regularize
# Out:
# C:\Users\Josh\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Josh\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
hi_inf_train=hi_inf_train.drop('OverallQual',axis=1)
hi_inf_train.head()
# Out:
#    GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF  OverallQualReg  \
# 0       1710         548          856       856            2100
# 1       1262         460         1262      1262            1800
# 2       1786         608          920       920            2100
# 3       1717         642          756       961            2100
# 4       2198         836         1145      1145            2400
#
#    OverallQualSquared
# 0               882.0
# 1               648.0
# 2               882.0
# 3               882.0
# 4              1152.0

# %%
hi_inf_train[hi_inf_train.isnull().any(axis=1)] #Checking for null entries
# Out:
# Empty DataFrame
# Columns: [GrLivArea, GarageArea, TotalBsmtSF, 1stFlrSF, OverallQualReg, OverallQualSquared]
# Index: []

# %%
#hi_inf_train=hi_inf_train.fillna(0)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()

x_train=hi_inf_train
y_train=train['SalePrice']


reg.fit(x_train,y_train)
reg.score(x_train,y_train)
# Out:
# 0.78257557503554698

# %%
reg.coef_
# Out:
# array([  41.72075656,   51.93263194,   21.290625  ,    6.02248132,
#        -104.44720005,  259.69600333])

# %%
hi_inf_test=test[['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF','OverallQual']]

#regularize the qual
hi_inf_test['OverallQualReg']=hi_inf_test['OverallQual']*300
hi_inf_test['OverallQualSquared']=(hi_inf_test['OverallQualReg']*hi_inf_test['OverallQualReg'])/5000 #squared and divided by 5,000 to regularize
# Out:
# C:\Users\Josh\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Josh\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
hi_inf_test=hi_inf_test.drop('OverallQual',axis=1)
x_test=hi_inf_test

# %%
x_test[x_test.isnull().any(axis=1)]  #Look for null values
# Out:
#       GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF  OverallQualReg  \
# 660         896       280.0          NaN       896            1200
# 1116       1828         NaN        859.0       942            1500
#
#       OverallQualSquared
# 660                288.0
# 1116               450.0

# %%
x_test=x_test.fillna(0) #Fill Null garage area and basement with 0
x_test[x_test.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [GrLivArea, GarageArea, TotalBsmtSF, 1stFlrSF, OverallQualReg, OverallQualSquared]
# Index: []

# %%
y_pred=reg.predict(x_test) #Abs is a temporary fix to deal with the prices which, for some reason, were negative and so invalid.

# %%
my_submission=pd.DataFrame(y_pred)
my_submission['Id']=test['Id']
my_submission.columns=['SalePrice','Id']
my_submission=my_submission[['Id','SalePrice']]

# %%
my_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  131558.098317
# 1  1462  160125.638186
# 2  1463  150432.208303
# 3  1464  168797.020239
# 4  1465  235036.375153

# %%
my_submission[my_submission.SalePrice<0]
# Out:
# Empty DataFrame
# Columns: [Id, SalePrice]
# Index: []

# %%
my_submission.to_csv('regularizedOverallQual-some-inf-feat-linear-1', index=False)
